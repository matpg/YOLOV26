# %% [markdown]
# <a href="https://colab.research.google.com/github/matpg/YOLOV26/blob/main/docs/examples/sam3_interactive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Interactive Segmentation with SAM3
#
# [![image](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/opengeos/segment-geospatial/blob/main/docs/examples/sam3_interactive.ipynb)
#
# This notebook demonstrates how to segment remote sensing images interactively using the Segment Anything Model 3 (SAM3).
#
# ## Installation
#
# First, make sure you have the required dependencies installed:

# %%
# %pip install "segment-geospatial[samgeo3]"
# Out:
# Collecting segment-geospatial[samgeo3]
#   Downloading segment_geospatial-1.3.2-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: gdown in /usr/local/lib/python3.12/dist-packages (from segment-geospatial[samgeo3]) (5.2.1)
# Requirement already satisfied: geopandas in /usr/local/lib/python3.12/dist-packages (from segment-geospatial[samgeo3]) (1.1.3)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (from segment-geospatial[samgeo3]) (1.7.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from segment-geospatial[samgeo3]) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from segment-geospatial[samgeo3]) (2.0.2)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.12/dist-packages (from segment-geospatial[samgeo3]) (4.13.0.92)
# Collecting patool (from segment-geospatial[samgeo3])
#   Downloading patool-4.0.4-py2.py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from segment-geospatial[samgeo3]) (11.3.0)
# Requirement already satisfied: pyproj in /usr/local/lib/python3.12/dist-packages (from segment-geospatial[samgeo3]) (3.7.2)
# Requirement already satisfied: rasterio in /usr/local/lib/python3.12/dist-packages (from segment-geospatial[samgeo3]) (1.5.0)
# Collecting segment_anything (from segment-geospatial[samgeo3])
#   Downloading segment_anything-1.0-py3-none-any.whl.metadata (487 bytes)
# Requirement already satisfied: shapely in /usr/local/lib/python3.12/dist-packages (from segment-geospatial[samgeo3]) (2.1.2)
# Collecting smoothify (from segment-geospatial[samgeo3])
#   Downloading smoothify-0.2.2-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from segment-geospatial[samgeo3]) (2.10.0+cpu)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from segment-geospatial[samgeo3]) (0.25.0+cpu)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from segment-geospatial[samgeo3]) (4.67.3)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.12/dist-packages (from segment-geospatial[samgeo3]) (2025.11.0)
# Collecting sam3 (from segment-geospatial[samgeo3])
#   Downloading sam3-0.1.3-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from segment-geospatial[samgeo3]) (1.6.1)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from segment-geospatial[samgeo3]) (0.25.2)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (from segment-geospatial[samgeo3]) (5.0.0)
# Collecting buildingregulariser (from segment-geospatial[samgeo3])
#   Downloading buildingregulariser-0.2.4-py3-none-any.whl.metadata (7.2 kB)
# Collecting leafmap (from segment-geospatial[samgeo3])
#   Downloading leafmap-0.61.1-py2.py3-none-any.whl.metadata (17 kB)
# Collecting localtileserver (from segment-geospatial[samgeo3])
#   Downloading localtileserver-0.11.0-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: spacy in /usr/local/lib/python3.12/dist-packages (from segment-geospatial[samgeo3]) (3.8.11)
# Collecting triton>=3.5.1 (from segment-geospatial[samgeo3])
#   Downloading triton-3.6.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: xarray in /usr/local/lib/python3.12/dist-packages (from segment-geospatial[samgeo3]) (2025.12.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers->segment-geospatial[samgeo3]) (3.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers->segment-geospatial[samgeo3]) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers->segment-geospatial[samgeo3]) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers->segment-geospatial[samgeo3]) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers->segment-geospatial[samgeo3]) (0.22.2)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers->segment-geospatial[samgeo3]) (0.24.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers->segment-geospatial[samgeo3]) (0.7.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->segment-geospatial[samgeo3]) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->segment-geospatial[samgeo3]) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->segment-geospatial[samgeo3]) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->segment-geospatial[samgeo3]) (0.24.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->segment-geospatial[samgeo3]) (4.15.0)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from geopandas->segment-geospatial[samgeo3]) (0.12.1)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from geopandas->segment-geospatial[samgeo3]) (2.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from pyproj->segment-geospatial[samgeo3]) (2026.2.25)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown->segment-geospatial[samgeo3]) (4.13.5)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.12/dist-packages (from gdown->segment-geospatial[samgeo3]) (2.32.4)
# Requirement already satisfied: anywidget in /usr/local/lib/python3.12/dist-packages (from leafmap->segment-geospatial[samgeo3]) (0.9.21)
# Requirement already satisfied: bqplot in /usr/local/lib/python3.12/dist-packages (from leafmap->segment-geospatial[samgeo3]) (0.12.45)
# Collecting duckdb>=1.4.1 (from leafmap->segment-geospatial[samgeo3])
#   Downloading duckdb-1.5.1-cp312-cp312-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: folium in /usr/local/lib/python3.12/dist-packages (from leafmap->segment-geospatial[samgeo3]) (0.20.0)
# Collecting geojson (from leafmap->segment-geospatial[samgeo3])
#   Downloading geojson-3.2.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: ipyevents in /usr/local/lib/python3.12/dist-packages (from leafmap->segment-geospatial[samgeo3]) (2.0.4)
# Requirement already satisfied: ipyfilechooser in /usr/local/lib/python3.12/dist-packages (from leafmap->segment-geospatial[samgeo3]) (0.6.0)
# Requirement already satisfied: ipyleaflet in /usr/local/lib/python3.12/dist-packages (from leafmap->segment-geospatial[samgeo3]) (0.20.0)
# Collecting ipyvue<1.12.0 (from leafmap->segment-geospatial[samgeo3])
#   Downloading ipyvue-1.11.3-py2.py3-none-any.whl.metadata (987 bytes)
# Collecting ipyvuetify (from leafmap->segment-geospatial[samgeo3])
#   Downloading ipyvuetify-1.11.3-py2.py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.12/dist-packages (from leafmap->segment-geospatial[samgeo3]) (7.7.1)
# Collecting maplibre (from leafmap->segment-geospatial[samgeo3])
#   Downloading maplibre-0.3.6-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (from leafmap->segment-geospatial[samgeo3]) (5.24.1)
# Collecting pystac-client (from leafmap->segment-geospatial[samgeo3])
#   Downloading pystac_client-0.9.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: python-box in /usr/local/lib/python3.12/dist-packages (from leafmap->segment-geospatial[samgeo3]) (7.4.1)
# Requirement already satisfied: scooby in /usr/local/lib/python3.12/dist-packages (from leafmap->segment-geospatial[samgeo3]) (0.11.0)
# Collecting whiteboxgui (from leafmap->segment-geospatial[samgeo3])
#   Downloading whiteboxgui-2.3.0-py2.py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from localtileserver->segment-geospatial[samgeo3]) (8.3.1)
# Requirement already satisfied: flask<4,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from localtileserver->segment-geospatial[samgeo3]) (3.1.3)
# Collecting Flask-Caching (from localtileserver->segment-geospatial[samgeo3])
#   Downloading Flask_Caching-2.3.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting flask-cors (from localtileserver->segment-geospatial[samgeo3])
#   Downloading flask_cors-6.0.2-py3-none-any.whl.metadata (5.3 kB)
# Collecting flask-restx>=1.3.0 (from localtileserver->segment-geospatial[samgeo3])
#   Downloading flask_restx-1.3.2-py2.py3-none-any.whl.metadata (9.3 kB)
# Collecting rio-tiler (from localtileserver->segment-geospatial[samgeo3])
#   Downloading rio_tiler-9.0.4-py3-none-any.whl.metadata (11 kB)
# Collecting rio-cogeo (from localtileserver->segment-geospatial[samgeo3])
#   Downloading rio_cogeo-7.0.1-py3-none-any.whl.metadata (6.1 kB)
# Collecting server-thread (from localtileserver->segment-geospatial[samgeo3])
#   Downloading server_thread-0.3.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: werkzeug in /usr/local/lib/python3.12/dist-packages (from localtileserver->segment-geospatial[samgeo3]) (3.1.6)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->segment-geospatial[samgeo3]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->segment-geospatial[samgeo3]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->segment-geospatial[samgeo3]) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->segment-geospatial[samgeo3]) (1.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->segment-geospatial[samgeo3]) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->segment-geospatial[samgeo3]) (2.9.0.post0)
# Requirement already satisfied: affine in /usr/local/lib/python3.12/dist-packages (from rasterio->segment-geospatial[samgeo3]) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from rasterio->segment-geospatial[samgeo3]) (25.4.0)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.12/dist-packages (from rasterio->segment-geospatial[samgeo3]) (0.7.2)
# Requirement already satisfied: timm>=1.0.17 in /usr/local/lib/python3.12/dist-packages (from sam3->segment-geospatial[samgeo3]) (1.0.25)
# Collecting ftfy<6.4.0,>=6.1.1 (from sam3->segment-geospatial[samgeo3])
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting iopath<0.2.0,>=0.1.10 (from sam3->segment-geospatial[samgeo3])
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 3.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting decord<0.7.0,>=0.6.0 (from sam3->segment-geospatial[samgeo3])
#   Downloading decord-0.6.0-py3-none-manylinux2010_x86_64.whl.metadata (422 bytes)
# Requirement already satisfied: einops<0.9.0,>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from sam3->segment-geospatial[samgeo3]) (0.8.2)
# Requirement already satisfied: pycocotools<2.1.0,>=2.0.10 in /usr/local/lib/python3.12/dist-packages (from sam3->segment-geospatial[samgeo3]) (2.0.11)
# Requirement already satisfied: scipy>=1.11.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->segment-geospatial[samgeo3]) (1.16.3)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image->segment-geospatial[samgeo3]) (3.6.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image->segment-geospatial[samgeo3]) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->segment-geospatial[samgeo3]) (2026.3.3)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->segment-geospatial[samgeo3]) (0.5)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->segment-geospatial[samgeo3]) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->segment-geospatial[samgeo3]) (3.6.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.12/dist-packages (from spacy->segment-geospatial[samgeo3]) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from spacy->segment-geospatial[samgeo3]) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.12/dist-packages (from spacy->segment-geospatial[samgeo3]) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy->segment-geospatial[samgeo3]) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy->segment-geospatial[samgeo3]) (3.0.12)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /usr/local/lib/python3.12/dist-packages (from spacy->segment-geospatial[samgeo3]) (8.3.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.12/dist-packages (from spacy->segment-geospatial[samgeo3]) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.12/dist-packages (from spacy->segment-geospatial[samgeo3]) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.12/dist-packages (from spacy->segment-geospatial[samgeo3]) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from spacy->segment-geospatial[samgeo3]) (0.4.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.12/dist-packages (from spacy->segment-geospatial[samgeo3]) (2.12.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from spacy->segment-geospatial[samgeo3]) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from spacy->segment-geospatial[samgeo3]) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->segment-geospatial[samgeo3]) (1.14.0)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from flask<4,>=2.0.0->localtileserver->segment-geospatial[samgeo3]) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from flask<4,>=2.0.0->localtileserver->segment-geospatial[samgeo3]) (2.2.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from flask<4,>=2.0.0->localtileserver->segment-geospatial[samgeo3]) (3.0.3)
# Collecting aniso8601>=0.82 (from flask-restx>=1.3.0->localtileserver->segment-geospatial[samgeo3])
#   Downloading aniso8601-10.0.1-py2.py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.12/dist-packages (from flask-restx>=1.3.0->localtileserver->segment-geospatial[samgeo3]) (4.26.0)
# Requirement already satisfied: referencing in /usr/local/lib/python3.12/dist-packages (from flask-restx>=1.3.0->localtileserver->segment-geospatial[samgeo3]) (0.37.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.12/dist-packages (from flask-restx>=1.3.0->localtileserver->segment-geospatial[samgeo3]) (6.5.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from ftfy<6.4.0,>=6.1.1->sam3->segment-geospatial[samgeo3]) (0.6.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub->segment-geospatial[samgeo3]) (4.12.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub->segment-geospatial[samgeo3]) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub->segment-geospatial[samgeo3]) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub->segment-geospatial[samgeo3]) (0.16.0)
# Collecting portalocker (from iopath<0.2.0,>=0.1.10->sam3->segment-geospatial[samgeo3])
#   Downloading portalocker-3.2.0-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->leafmap->segment-geospatial[samgeo3]) (6.17.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->leafmap->segment-geospatial[samgeo3]) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->leafmap->segment-geospatial[samgeo3]) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->leafmap->segment-geospatial[samgeo3]) (3.6.10)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->leafmap->segment-geospatial[samgeo3]) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->leafmap->segment-geospatial[samgeo3]) (3.0.16)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->geopandas->segment-geospatial[samgeo3]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->geopandas->segment-geospatial[samgeo3]) (2025.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy->segment-geospatial[samgeo3]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy->segment-geospatial[samgeo3]) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy->segment-geospatial[samgeo3]) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->segment-geospatial[samgeo3]) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown->segment-geospatial[samgeo3]) (3.4.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown->segment-geospatial[samgeo3]) (2.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->segment-geospatial[samgeo3]) (1.3.0)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.4->spacy->segment-geospatial[samgeo3]) (1.3.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.4->spacy->segment-geospatial[samgeo3]) (0.1.5)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub->segment-geospatial[samgeo3]) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub->segment-geospatial[samgeo3]) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub->segment-geospatial[samgeo3]) (0.0.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from weasel<0.5.0,>=0.4.2->spacy->segment-geospatial[samgeo3]) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.12/dist-packages (from weasel<0.5.0,>=0.4.2->spacy->segment-geospatial[samgeo3]) (7.5.1)
# Requirement already satisfied: psygnal>=0.8.1 in /usr/local/lib/python3.12/dist-packages (from anywidget->leafmap->segment-geospatial[samgeo3]) (0.15.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown->segment-geospatial[samgeo3]) (2.8.3)
# Requirement already satisfied: traittypes>=0.0.6 in /usr/local/lib/python3.12/dist-packages (from bqplot->leafmap->segment-geospatial[samgeo3]) (0.2.3)
# Collecting cachelib>=0.9.0 (from Flask-Caching->localtileserver->segment-geospatial[samgeo3])
#   Downloading cachelib-0.13.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from folium->leafmap->segment-geospatial[samgeo3]) (0.8.2)
# Requirement already satisfied: jupyter-leaflet<0.21,>=0.20 in /usr/local/lib/python3.12/dist-packages (from ipyleaflet->leafmap->segment-geospatial[samgeo3]) (0.20.0)
# Collecting eval-type-backport (from maplibre->leafmap->segment-geospatial[samgeo3])
#   Downloading eval_type_backport-0.3.1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly->leafmap->segment-geospatial[samgeo3]) (9.1.4)
# Collecting pystac>=1.10.0 (from pystac[validation]>=1.10.0->pystac-client->leafmap->segment-geospatial[samgeo3])
#   Downloading pystac-1.14.3-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown->segment-geospatial[samgeo3]) (1.7.1)
# Collecting morecantile<8.0,>=5.0 (from rio-cogeo->localtileserver->segment-geospatial[samgeo3])
#   Downloading morecantile-7.0.3-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.12/dist-packages (from rio-tiler->localtileserver->segment-geospatial[samgeo3]) (6.2.6)
# Collecting color-operations (from rio-tiler->localtileserver->segment-geospatial[samgeo3])
#   Downloading color_operations-0.2.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.12/dist-packages (from rio-tiler->localtileserver->segment-geospatial[samgeo3]) (2.14.1)
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.12/dist-packages (from server-thread->localtileserver->segment-geospatial[samgeo3]) (0.42.0)
# Requirement already satisfied: ipytree in /usr/local/lib/python3.12/dist-packages (from whiteboxgui->leafmap->segment-geospatial[samgeo3]) (0.2.2)
# Collecting whitebox (from whiteboxgui->leafmap->segment-geospatial[samgeo3])
#   Downloading whitebox-2.3.6-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap->segment-geospatial[samgeo3]) (1.8.15)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap->segment-geospatial[samgeo3]) (7.4.9)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap->segment-geospatial[samgeo3]) (0.2.1)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap->segment-geospatial[samgeo3]) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap->segment-geospatial[samgeo3]) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap->segment-geospatial[samgeo3]) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap->segment-geospatial[samgeo3]) (6.5.1)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets->leafmap->segment-geospatial[samgeo3])
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (4.9.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema->flask-restx>=1.3.0->localtileserver->segment-geospatial[samgeo3]) (2025.9.1)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema->flask-restx>=1.3.0->localtileserver->segment-geospatial[samgeo3]) (0.30.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface_hub->segment-geospatial[samgeo3]) (4.0.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.4.2->spacy->segment-geospatial[samgeo3]) (2.1.2)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.12/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (6.5.7)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (0.8.6)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->leafmap->segment-geospatial[samgeo3]) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->leafmap->segment-geospatial[samgeo3]) (5.9.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface_hub->segment-geospatial[samgeo3]) (0.1.2)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (25.1.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (7.17.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (0.24.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (1.3.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (0.7.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->leafmap->segment-geospatial[samgeo3]) (4.9.4)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.12/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (0.2.4)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (6.3.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (3.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (2.21.2)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.12/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (25.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (1.4.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.12/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (2.14.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (3.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (0.5.4)
# Requirement already satisfied: overrides>=5.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (7.7.0)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (1.9.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (4.0.0)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (0.1.1)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (25.10.0)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (1.4.0)
# Downloading triton-3.6.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (188.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.3/188.3 MB 1.8 MB/s eta 0:00:00
# Downloading buildingregulariser-0.2.4-py3-none-any.whl (19 kB)
# Downloading leafmap-0.61.1-py2.py3-none-any.whl (666 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 666.8/666.8 kB 36.7 MB/s eta 0:00:00
# Downloading localtileserver-0.11.0-py3-none-any.whl (30 kB)
# Downloading patool-4.0.4-py2.py3-none-any.whl (88 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.6/88.6 kB 7.5 MB/s eta 0:00:00
# Downloading sam3-0.1.3-py3-none-any.whl (506 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.8/506.8 kB 32.5 MB/s eta 0:00:00
# Downloading segment_anything-1.0-py3-none-any.whl (36 kB)
# Downloading segment_geospatial-1.3.2-py2.py3-none-any.whl (150 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.8/150.8 kB 11.3 MB/s eta 0:00:00
# Downloading smoothify-0.2.2-py3-none-any.whl (16 kB)
# Downloading decord-0.6.0-py3-none-manylinux2010_x86_64.whl (13.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 74.4 MB/s eta 0:00:00
# Downloading duckdb-1.5.1-cp312-cp312-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl (21.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.4/21.4 MB 70.8 MB/s eta 0:00:00
# Downloading flask_restx-1.3.2-py2.py3-none-any.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 88.1 MB/s eta 0:00:00
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.4 MB/s eta 0:00:00
# Downloading ipyvue-1.11.3-py2.py3-none-any.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 64.6 MB/s eta 0:00:00
# Downloading Flask_Caching-2.3.1-py3-none-any.whl (28 kB)
# Downloading flask_cors-6.0.2-py3-none-any.whl (13 kB)
# Downloading geojson-3.2.0-py3-none-any.whl (15 kB)
# Downloading ipyvuetify-1.11.3-py2.py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 107.3 MB/s eta 0:00:00
# Downloading maplibre-0.3.6-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 59.8 MB/s eta 0:00:00
# Downloading pystac_client-0.9.0-py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 3.5 MB/s eta 0:00:00
# Downloading rio_cogeo-7.0.1-py3-none-any.whl (21 kB)
# Downloading rio_tiler-9.0.4-py3-none-any.whl (287 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.5/287.5 kB 21.8 MB/s eta 0:00:00
# Downloading server_thread-0.3.0-py3-none-any.whl (6.6 kB)
# Downloading whiteboxgui-2.3.0-py2.py3-none-any.whl (108 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.6/108.6 kB 9.0 MB/s eta 0:00:00
# Downloading aniso8601-10.0.1-py2.py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 4.4 MB/s eta 0:00:00
# Downloading cachelib-0.13.0-py3-none-any.whl (20 kB)
# Downloading morecantile-7.0.3-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.3 MB/s eta 0:00:00
# Downloading pystac-1.14.3-py3-none-any.whl (208 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.5/208.5 kB 16.0 MB/s eta 0:00:00
# Downloading color_operations-0.2.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (204 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.3/204.3 kB 15.6 MB/s eta 0:00:00
# Downloading eval_type_backport-0.3.1-py3-none-any.whl (6.1 kB)
# Downloading portalocker-3.2.0-py3-none-any.whl (22 kB)
# Downloading whitebox-2.3.6-py2.py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.0/74.0 kB 6.3 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 49.5 MB/s eta 0:00:00
# Building wheels for collected packages: iopath
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31527 sha256=51b8fffef381b5779b0af7dbe3595552a5db4660eb7db592e280da4ae62ae4df
#   Stored in directory: /root/.cache/pip/wheels/7c/96/04/4f5f31ff812f684f69f40cb1634357812220aac58d4698048c
# Successfully built iopath
# Installing collected packages: segment_anything, aniso8601, whitebox, triton, portalocker, patool, jedi, geojson, ftfy, eval-type-backport, duckdb, decord, color-operations, cachelib, server-thread, pystac, iopath, morecantile, maplibre, flask-cors, Flask-Caching, smoothify, rio-tiler, rio-cogeo, flask-restx, buildingregulariser, segment-geospatial, pystac-client, localtileserver, sam3, ipyvue, whiteboxgui, ipyvuetify, leafmap
#   Attempting uninstall: duckdb
#     Found existing installation: duckdb 1.3.2
#     Uninstalling duckdb-1.3.2:
#       Successfully uninstalled duckdb-1.3.2
# Successfully installed Flask-Caching-2.3.1 aniso8601-10.0.1 buildingregulariser-0.2.4 cachelib-0.13.0 color-operations-0.2.0 decord-0.6.0 duckdb-1.5.1 eval-type-backport-0.3.1 flask-cors-6.0.2 flask-restx-1.3.2 ftfy-6.3.1 geojson-3.2.0 iopath-0.1.10 ipyvue-1.11.3 ipyvuetify-1.11.3 jedi-0.19.2 leafmap-0.61.1 localtileserver-0.11.0 maplibre-0.3.6 morecantile-7.0.3 patool-4.0.4 portalocker-3.2.0 pystac-1.14.3 pystac-client-0.9.0 rio-cogeo-7.0.1 rio-tiler-9.0.4 sam3-0.1.3 segment-geospatial-1.3.2 segment_anything-1.0 server-thread-0.3.0 smoothify-0.2.2 triton-3.6.0 whitebox-2.3.6 whiteboxgui-2.3.0

# %%
# %pip install transformers==5.0.0rc0
# Out:
# Collecting transformers==5.0.0rc0
#   Downloading transformers-5.0.0rc0-py3-none-any.whl.metadata (35 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers==5.0.0rc0) (3.25.2)
# Requirement already satisfied: huggingface-hub<2.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from transformers==5.0.0rc0) (1.7.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers==5.0.0rc0) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers==5.0.0rc0) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers==5.0.0rc0) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers==5.0.0rc0) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers==5.0.0rc0) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers==5.0.0rc0) (0.22.2)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers==5.0.0rc0) (0.24.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers==5.0.0rc0) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers==5.0.0rc0) (4.67.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.0.0->transformers==5.0.0rc0) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.0.0->transformers==5.0.0rc0) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.0.0->transformers==5.0.0rc0) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.0.0->transformers==5.0.0rc0) (0.24.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.0.0->transformers==5.0.0rc0) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==5.0.0rc0) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==5.0.0rc0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==5.0.0rc0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==5.0.0rc0) (2026.2.25)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.0.0->transformers==5.0.0rc0) (4.12.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.0.0->transformers==5.0.0rc0) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.0.0->transformers==5.0.0rc0) (0.16.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.0.0->transformers==5.0.0rc0) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.0.0->transformers==5.0.0rc0) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.0.0->transformers==5.0.0rc0) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.0.0->transformers==5.0.0rc0) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.0.0->transformers==5.0.0rc0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.0.0->transformers==5.0.0rc0) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0,>=1.0.0->transformers==5.0.0rc0) (0.1.2)
# Downloading transformers-5.0.0rc0-py3-none-any.whl (9.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 69.3 MB/s eta 0:00:00
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.0.0
#     Uninstalling transformers-5.0.0:
#       Successfully uninstalled transformers-5.0.0
# Successfully installed transformers-5.0.0rc0

# %% [markdown]
# ## Import Libraries

# %%
import leafmap
from samgeo import SamGeo3, download_file

# %% [markdown]
# ## Download Sample Data
#
# Let's download a sample satellite image covering the University of California, Berkeley, for testing:

# %%
url = "https://huggingface.co/datasets/giswqs/geospatial/resolve/main/uc_berkeley.tif"
image_path = download_file(url)

# %%
m = leafmap.Map()
m.add_raster(image_path, layer_name="Satellite image")
m

# %% [markdown]
# ## Request access to SAM3
#
# To use SAM3, you need to request access by filling out this form on Hugging Face: https://huggingface.co/facebook/sam3
#
# Once you have access, uncomment the following code block and run it.

# %%
# from huggingface_hub import login
# login()

# %% [markdown]
# ## Initialize SAM3
#
# When initializing SAM3, you can choose the backend from "meta", or "transformers".

# %%
sam3 = SamGeo3(
    backend="transformers", device=None, checkpoint_path=None, load_from_HF=True
)

# %% [markdown]
# ## Set the image
#
# You can set the image by either passing the image path or the image URL.

# %%
sam3.set_image(image_path)

# %% [markdown]
# ## Generate masks with text prompt

# %%
sam3.generate_masks(prompt="building")

# %%
sam3.save_masks("masks.tif")

# %% [markdown]
# ## Show the results

# %%
sam3.show_anns()

# %% [markdown]
# ![annotation](https://github.com/user-attachments/assets/64323223-35a2-4e03-9cee-1b60fa0c12af)

# %%
sam3.show_masks()

# %% [markdown]
# ## Interactive segmentation
#
# Enter a text prompt or draw a rectangle on the map, then click on the **Segment** button to perform instance segmentation.

# %%
sam3.show_map(height="700px", min_size=10)

# %% [markdown]
# Segmentation by text prompts.

# %% [markdown]
# ![image](https://github.com/user-attachments/assets/535d69b5-8e0f-46a3-8f8b-9fc602628a7f)

# %% [markdown]
# Segmentation by bounding boxes.

# %% [markdown]
# ![](https://github.com/user-attachments/assets/3d6a5aed-8f3f-4350-ba26-04a84328c50d)
